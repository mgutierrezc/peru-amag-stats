# %% [markdown]
# ### Importing base packages

# %%
import pandas as pd
import numpy as np
import json

# %%
path = "D:\Accesos directos\Trabajo\World Bank\Peru Amag\peru-amag-stats\Data\Baseline raw"
test_app_data = "all_apps_wide_2021-06-29-2.csv"
app_data = pd.read_csv(path + "\\" + test_app_data)
# app_data[~app_data["iat.1.player.iat_tables"].isnull()]["iat.1.player.iat_tables"]

# %%
app_data[~app_data["iat.1.player.iat_tables"].isnull()]["iat.1.player.iat_tables"].iloc[0]
# Out:
# '[[{"period":1,"left_main_category":"Masculino","right_main_category":"Femenino","left_sub_category":null,"right_sub_category":null,"item":"Esposa","correct_side":100,"timestamp":1623955869484,"elapsed_time":3917,"pressed_key":73,"pressed_side":100},{"period":2,"left_main_category":"Masculino","right_main_category":"Femenino","left_sub_category":null,"right_sub_category":null,"item":"Niña","correct_side":100,"timestamp":1623955870380,"elapsed_time":894,"pressed_key":73,"pressed_side":100},{"period":3,"left_main_category":"Masculino","right_main_category":"Femenino","left_sub_category":null,"right_sub_category":null,"item":"Niña","correct_side":100,"timestamp":1623955872220,"elapsed_time":1839,"pressed_key":73,"pressed_side":100},{"period":4,"left_main_category":"Masculino","right_main_category":"Femenino","left_sub_category":null,"right_sub_category":null,"item":"Tio","correct_side":99,"timestamp":1623955873132,"elapsed_time":912,"pressed_key":69,"pressed_side":99},{"period":5,"left_
# ...
